# %%
# !pip install transformers datasets sentence-transformers diffusers accelerate huggingface_hub[cli] torchvision pillow sklearn --q
# Out:
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
from transformers import pipeline
classifier = pipeline("sentiment-analysis",model='distilbert-base-uncased-finetuned-sst-2-english')
text=input('enter a text to analysis')
result=classifier(text)
print(result)
# Out:
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# enter a text to analysishi
# [{'label': 'POSITIVE', 'score': 0.9983267188072205}]

# %%
from transformers import pipeline
generator=pipeline('text-generation',model='gpt2')
prompt='in a feature where healthcare is fully centralised,'
outputs=generator(prompt,max_new_tokens=80,do_sample=True,temperature=0.8,top_p=0.9,num_return_sequences=2)
for i,output in enumerate(outputs):
  print(f"nOutput {i}:")
  print(output['generated_text'])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=80) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# nOutput 0:
# in a feature where healthcare is fully centralised, you can do it at home. You'll find a range of free online healthcare services for people who are not in the UK, and have access to a wide range of private healthcare services.
#
# ...

# %%
from getpass import getpass
import os
HF_TOKEN=getpass('enter your token:')
os.environ['HF_TOKEN']=HF_TOKEN
# Out:
# enter your token:··········

# %% [markdown]
# BASIC ASSISTAN USING HUGGING FACE INFERENCE API

# %%
import os
from huggingface_hub import InferenceClient
MODEL_ID = "meta-llama/Meta-Llama-3-8B-Instruct"
client = InferenceClient(api_key=os.environ["HF_TOKEN"],model=MODEL_ID)
def extract_text(resp):
    try:
        return resp.choices[0].message.content
    except Exception:
        try:
            return resp['choices'][0]['message']['content']
        except:
            return str(resp)
messages = [{"role": "system","content": "You are a helpful AI assistant." },
    {"role": "user","content": "Explain Agentic AI in simple words."}]

response = client.chat_completion(messages=messages,max_tokens=200,temperature=0.7)
print(extract_text(response))
# Out:
# Agentic AI refers to a type of Artificial Intelligence (AI) that is designed to act autonomously, making decisions and taking actions on its own, without explicit human direction. Think of it like a "mini-me" that can think and act independently, but still within certain boundaries.
#
# Agentic AI is programmed to learn, reason, and make decisions based on its own goals and motivations, rather than simply following pre-defined rules. This allows it to adapt to new situations, make mistakes, and learn from them, just like humans do.
#
# For example, imagine a self-driving car that can recognize and respond to unexpected road hazards, or a chatbot that can have a conversation with a human, understanding humor and context. These are all examples of Agentic AI in action!
#
# The key characteristics of Agentic AI include:
#
# 1. Autonomy: The ability to make decisions and take actions without human intervention.
# ...
