# %%
# !pip install requests beautifulsoup4 chromadb sentence-transformers -q
print("Installation completed!")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 3.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 61.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 21.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 93.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 71.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 10.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.9 MB/s eta 0:00:00
# ...

# %%
import requests
from bs4 import BeautifulSoup
import chromadb
from sentence_transformers import SentenceTransformer

# %%
url = "https://sece.ac.in/coe-data-science/"

# %%
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

text = soup.get_text(separator="\n")
print(text[:1000])
# Out:
# Centre of Excellence - Data Science - Sri Eshwar Engineering College
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 		Skip to content
#
#
#
#
#
#
# Sri Eshwar Engineering College
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# International Internship 2026 @ SECE
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Campus tour
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Admission 2025
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# TNEA
#
# CODE
# 2739
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Study In India
#
#
# Alumni
#
#
# ERP
#
#
# Careers
#
#
# IQAC
#
#
# NBA DCP
#
#
# Audited Statements
#
#
# SDG CELL
#
#
# Quick Links
#
#
#
#
# Research Ethics Committee
#
# Examination Committee
#
# ...

# %%
clean_text = text.strip()

lines = clean_text.split("\n")
documents = []

for line in lines:
    line = line.strip()
    if line:
        documents.append(line)

print("Total documents:", len(documents))
print(documents[:10])
# Out:
# Total documents: 787
# ['Centre of Excellence - Data Science - Sri Eshwar Engineering College', 'Skip to content', 'Sri Eshwar Engineering College', 'International Internship 2026 @ SECE', 'Campus tour', 'Admission 2025', 'TNEA', 'CODE', '2739', 'Study In India']

# %%
with open("sece_coe_datascience.txt", "w", encoding="utf-8") as file:
    file.write(clean_text)

print("Text file created successfully!")
# Out:
# Text file created successfully!

# %%
from google.colab import files
files.download("sece_coe_datascience.txt")
