# %%
# !pip install chromadb sentence-transformers -q
print('completeted installation!')
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 997.3 kB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 35.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 11.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 72.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 36.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 13.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 15.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.5 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer
import chromadb

print('all libraries imported successfully!!')
print('version:', chromadb.__version__)
# Out:
# all libraries imported successfully!!
# version: 1.5.9

# %%
documents = [
    "Artificial Intelligence is transforming industries.",
    "Machine Learning is a subset of AI.",
    "Deep Learning uses neural networks.",
    "Python is widely used for AI development.",
    "ChromaDB is used for vehicle databases.",
]
query_keyword='vehicle'
for i,doc in enumerate(documents):
    if query_keyword in doc.lower():
      print('Found:',doc)
    else:
      print('Not Found:',doc)
print()
# Out:
# Not Found: Artificial Intelligence is transforming industries.
# Not Found: Machine Learning is a subset of AI.
# Not Found: Deep Learning uses neural networks.
# Not Found: Python is widely used for AI development.
# Found: ChromaDB is used for vehicle databases.

# %%
print('loading embed models............(may take one to 2 inutes0)')
model=SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
print('completeted loading embed models')
print('modelproduces vectors of size',model.get_sentence_embedding_dimension())
# Out:
# loading embed models............(may take one to 2 inutes0)
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# completeted loading embed models
# modelproduces vectors of size 384
# /tmp/ipykernel_886/3458290982.py:4: FutureWarning: The `get_sentence_embedding_dimension` method has been renamed to `get_embedding_dimension`.
#   print('modelproduces vectors of size',model.get_sentence_embedding_dimension())

# %%
sentence='etl is used to clean data'
embedding=model.encode(sentence)
print('input:',sentence)
print()
print('embedding type:',type(embedding))
print('embedding shape:',embedding.shape)
print('first 10 numbners:',embedding[:10].round(4))
print('min value:',embedding.min().round(4))
print('max value:',embedding.max().round(4))
# Out:
# input: etl is used to clean data
#
# embedding type: <class 'numpy.ndarray'>
# embedding shape: (384,)
# first 10 numbners: [-0.0555  0.0501  0.0355 -0.0242  0.0389 -0.1049  0.0364 -0.0279  0.0727
#   0.0302]
# min value: -0.1245
# max value: 0.1905

# %%
sentences = [
    "ETL is used to clean data.",
    "Machine learning models require quality datasets.",
    "Data Science helps in decision making.",
    "Semantic search uses embeddings.",
    "Python is widely used in AI applications."
]

for sentence in sentences:

    embedding = model.encode(sentence)

    print("Input:", sentence)
    print()

    print("Embedding type:", type(embedding))
    print("Embedding shape:", embedding.shape)
    print("First 10 numbers:", embedding[:10].round(4))
    print("Min value:", embedding.min().round(4))
    print("Max value:", embedding.max().round(4))
# Out:
# Input: ETL is used to clean data.
#
# Embedding type: <class 'numpy.ndarray'>
# Embedding shape: (384,)
# First 10 numbers: [-0.0575  0.0406  0.0308 -0.0253  0.0364 -0.1076  0.0212 -0.0202  0.0751
#   0.0335]
# Min value: -0.1308
# Max value: 0.1929
# Input: Machine learning models require quality datasets.
#
# Embedding type: <class 'numpy.ndarray'>
# Embedding shape: (384,)
# First 10 numbers: [ 0.002  -0.0511  0.0523  0.0231 -0.004  -0.0738 -0.1121 -0.0922 -0.0446
#  -0.0414]
# Min value: -0.1469
# Max value: 0.1686
# Input: Data Science helps in decision making.
#
# Embedding type: <class 'numpy.ndarray'>
# Embedding shape: (384,)
# First 10 numbers: [ 0.0127 -0.008  -0.0003  0.0111  0.0204 -0.076  -0.0021  0.0028 -0.0218
#   0.1054]
# Min value: -0.145
# Max value: 0.1431
# Input: Semantic search uses embeddings.
#
# Embedding type: <class 'numpy.ndarray'>
# Embedding shape: (384,)
# First 10 numbers: [ 0.011  -0.0186  0.0194  0.014   0.0193  0.0612 -0.0139  0.0026  0.0498
# ...

# %%
import numpy as np
def cosine_similarity(vec_a,vec_b):
  """Calculate cosine similarity between two vectors"""
  dot_product=np.dot(vec_a,vec_b)
  norm_a=np.linalg.norm(vec_a)
  norm_b=np.linalg.norm(vec_b)
  return dot_product/(norm_a*norm_b)
sim_01=cosine_similarity(embeddings[0],embeddings[1])
sim_02=cosine_similarity(embeddings[0],embeddings[2])
sim_12=cosine_similarity(embeddings[1],embeddings[2])
print('similarity 1:',sim_01)
print('similaruty 2":',sim_02)
print('similariy 3:',sim_12)
# Out:
# similarity 1: 0.14149441
# similaruty 2": 0.22385904
# similariy 3: 0.37366503
